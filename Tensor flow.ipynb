# %%
import numpy as np
import pandas as pd
import json
import csv
import random

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# Reading the data
data = pd.read_csv("news (1).csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
	sequences1, padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('glove.6B.50d.txt', encoding='cp1252', errors='replace') as f:
    for line in f:
        values = line.split()
        word = values[0]
        try:
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
        except ValueError:
            continue

# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
							input_length=max_length, weights=[
								embeddings_matrix],
							trainable=False),
	tf.keras.layers.Dropout(0.2),
	tf.keras.layers.Conv1D(64, 5, activation='relu'),
	tf.keras.layers.MaxPooling1D(pool_size=4),
	tf.keras.layers.LSTM(64),
	tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
			optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1D  (None, 12, 64)           0
#  )
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# C:\Users\KIIT\MachineLearning\Project\env\Lib\site-packages\keras\engine\training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 2s - loss: 0.6528 - accuracy: 0.5970 - val_loss: 0.5797 - val_accuracy: 0.6600 - 2s/epoch - 803us/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5752 - accuracy: 0.7026 - val_loss: 0.5404 - val_accuracy: 0.6833 - 2s/epoch - 564us/sample
# Epoch 3/50
# 2700/2700 - 1s - loss: 0.5450 - accuracy: 0.7319 - val_loss: 0.5396 - val_accuracy: 0.7200 - 1s/epoch - 520us/sample
# Epoch 4/50
# 2700/2700 - 1s - loss: 0.4951 - accuracy: 0.7644 - val_loss: 0.5040 - val_accuracy: 0.7333 - 993ms/epoch - 368us/sample
# Epoch 5/50
# 2700/2700 - 1s - loss: 0.4710 - accuracy: 0.7804 - val_loss: 0.5361 - val_accuracy: 0.7233 - 1s/epoch - 450us/sample
# Epoch 6/50
# 2700/2700 - 1s - loss: 0.4030 - accuracy: 0.8226 - val_loss: 0.5089 - val_accuracy: 0.7567 - 1s/epoch - 417us/sample
# Epoch 7/50
# 2700/2700 - 1s - loss: 0.3807 - accuracy: 0.8307 - val_loss: 0.5318 - val_accuracy: 0.7333 - 1s/epoch - 439us/sample
# Epoch 8/50
# 2700/2700 - 1s - loss: 0.3397 - accuracy: 0.8593 - val_loss: 0.5766 - val_accuracy: 0.7233 - 1s/epoch - 465us/sample
# Epoch 9/50
# 2700/2700 - 1s - loss: 0.2843 - accuracy: 0.8804 - val_loss: 0.5091 - val_accuracy: 0.7400 - 765ms/epoch - 283us/sample
# Epoch 10/50
# 2700/2700 - 1s - loss: 0.2767 - accuracy: 0.8804 - val_loss: 0.5517 - val_accuracy: 0.7667 - 1s/epoch - 500us/sample
# Epoch 11/50
# 2700/2700 - 1s - loss: 0.2422 - accuracy: 0.9015 - val_loss: 0.5766 - val_accuracy: 0.7600 - 1s/epoch - 447us/sample
# Epoch 12/50
# 2700/2700 - 1s - loss: 0.2076 - accuracy: 0.9226 - val_loss: 0.5459 - val_accuracy: 0.7767 - 1s/epoch - 516us/sample
# Epoch 13/50
# 2700/2700 - 1s - loss: 0.2081 - accuracy: 0.9167 - val_loss: 0.5778 - val_accuracy: 0.7533 - 1s/epoch - 389us/sample
# Epoch 14/50
# 2700/2700 - 1s - loss: 0.1839 - accuracy: 0.9300 - val_loss: 0.6779 - val_accuracy: 0.7700 - 1s/epoch - 442us/sample
# Epoch 15/50
# 2700/2700 - 1s - loss: 0.1719 - accuracy: 0.9315 - val_loss: 0.6055 - val_accuracy: 0.7633 - 1s/epoch - 505us/sample
# Epoch 16/50
# 2700/2700 - 1s - loss: 0.1648 - accuracy: 0.9359 - val_loss: 0.6470 - val_accuracy: 0.7733 - 1s/epoch - 493us/sample
# Epoch 17/50
# 2700/2700 - 1s - loss: 0.1499 - accuracy: 0.9404 - val_loss: 0.6736 - val_accuracy: 0.7733 - 1s/epoch - 479us/sample
# Epoch 18/50
# 2700/2700 - 1s - loss: 0.1466 - accuracy: 0.9448 - val_loss: 0.6483 - val_accuracy: 0.7600 - 1s/epoch - 404us/sample
# Epoch 19/50
# 2700/2700 - 1s - loss: 0.1330 - accuracy: 0.9504 - val_loss: 0.6564 - val_accuracy: 0.7600 - 957ms/epoch - 355us/sample
# Epoch 20/50
# 2700/2700 - 1s - loss: 0.1391 - accuracy: 0.9496 - val_loss: 0.6334 - val_accuracy: 0.7900 - 1s/epoch - 483us/sample
# Epoch 21/50
# 2700/2700 - 1s - loss: 0.1285 - accuracy: 0.9526 - val_loss: 0.6144 - val_accuracy: 0.7700 - 1s/epoch - 409us/sample
# Epoch 22/50
# 2700/2700 - 1s - loss: 0.1156 - accuracy: 0.9563 - val_loss: 0.6856 - val_accuracy: 0.7767 - 1s/epoch - 423us/sample
# Epoch 23/50
# 2700/2700 - 1s - loss: 0.1319 - accuracy: 0.9485 - val_loss: 0.7292 - val_accuracy: 0.7267 - 1s/epoch - 391us/sample
# Epoch 24/50
# 2700/2700 - 1s - loss: 0.1048 - accuracy: 0.9615 - val_loss: 0.7399 - val_accuracy: 0.7633 - 764ms/epoch - 283us/sample
# Epoch 25/50
# 2700/2700 - 1s - loss: 0.1069 - accuracy: 0.9581 - val_loss: 0.6545 - val_accuracy: 0.7533 - 846ms/epoch - 313us/sample
# Epoch 26/50
# 2700/2700 - 1s - loss: 0.1179 - accuracy: 0.9552 - val_loss: 0.6497 - val_accuracy: 0.7567 - 919ms/epoch - 340us/sample
# Epoch 27/50
# 2700/2700 - 1s - loss: 0.0932 - accuracy: 0.9656 - val_loss: 0.7582 - val_accuracy: 0.7667 - 939ms/epoch - 348us/sample
# Epoch 28/50
# 2700/2700 - 1s - loss: 0.0893 - accuracy: 0.9674 - val_loss: 0.7591 - val_accuracy: 0.7633 - 779ms/epoch - 289us/sample
# Epoch 29/50
# 2700/2700 - 1s - loss: 0.1063 - accuracy: 0.9589 - val_loss: 0.8691 - val_accuracy: 0.7467 - 1s/epoch - 419us/sample
# Epoch 30/50
# 2700/2700 - 1s - loss: 0.0945 - accuracy: 0.9641 - val_loss: 0.8514 - val_accuracy: 0.7600 - 1s/epoch - 391us/sample
# Epoch 31/50
# 2700/2700 - 1s - loss: 0.0924 - accuracy: 0.9633 - val_loss: 0.7193 - val_accuracy: 0.7700 - 973ms/epoch - 360us/sample
# Epoch 32/50
# 2700/2700 - 1s - loss: 0.0920 - accuracy: 0.9678 - val_loss: 0.8576 - val_accuracy: 0.7500 - 818ms/epoch - 303us/sample
# Epoch 33/50
# 2700/2700 - 1s - loss: 0.0645 - accuracy: 0.9767 - val_loss: 0.7991 - val_accuracy: 0.7600 - 982ms/epoch - 364us/sample
# Epoch 34/50
# 2700/2700 - 1s - loss: 0.0812 - accuracy: 0.9681 - val_loss: 0.9207 - val_accuracy: 0.7367 - 1s/epoch - 376us/sample
# Epoch 35/50
# 2700/2700 - 1s - loss: 0.0751 - accuracy: 0.9748 - val_loss: 0.7478 - val_accuracy: 0.7433 - 1s/epoch - 385us/sample
# Epoch 36/50
# 2700/2700 - 1s - loss: 0.0811 - accuracy: 0.9726 - val_loss: 0.7333 - val_accuracy: 0.7533 - 1s/epoch - 443us/sample
# Epoch 37/50
# 2700/2700 - 1s - loss: 0.0853 - accuracy: 0.9689 - val_loss: 0.7330 - val_accuracy: 0.7767 - 1s/epoch - 511us/sample
# Epoch 38/50
# 2700/2700 - 1s - loss: 0.0612 - accuracy: 0.9767 - val_loss: 0.9177 - val_accuracy: 0.7600 - 814ms/epoch - 301us/sample
# Epoch 39/50
# 2700/2700 - 1s - loss: 0.0608 - accuracy: 0.9767 - val_loss: 0.8733 - val_accuracy: 0.7533 - 757ms/epoch - 281us/sample
# Epoch 40/50
# 2700/2700 - 1s - loss: 0.0751 - accuracy: 0.9722 - val_loss: 0.7475 - val_accuracy: 0.7600 - 816ms/epoch - 302us/sample
# Epoch 41/50
# 2700/2700 - 1s - loss: 0.0688 - accuracy: 0.9730 - val_loss: 0.8925 - val_accuracy: 0.7567 - 1s/epoch - 498us/sample
# Epoch 42/50
# 2700/2700 - 1s - loss: 0.0749 - accuracy: 0.9719 - val_loss: 0.8961 - val_accuracy: 0.7467 - 1s/epoch - 401us/sample
# Epoch 43/50
# 2700/2700 - 1s - loss: 0.0533 - accuracy: 0.9815 - val_loss: 0.8592 - val_accuracy: 0.7567 - 957ms/epoch - 354us/sample
# Epoch 44/50
# 2700/2700 - 1s - loss: 0.0691 - accuracy: 0.9770 - val_loss: 0.8700 - val_accuracy: 0.7767 - 1s/epoch - 482us/sample
# Epoch 45/50
# 2700/2700 - 1s - loss: 0.0632 - accuracy: 0.9770 - val_loss: 0.8237 - val_accuracy: 0.7667 - 1s/epoch - 545us/sample
# Epoch 46/50
# 2700/2700 - 1s - loss: 0.0522 - accuracy: 0.9815 - val_loss: 1.0688 - val_accuracy: 0.7633 - 1s/epoch - 455us/sample
# Epoch 47/50
# 2700/2700 - 1s - loss: 0.0676 - accuracy: 0.9737 - val_loss: 0.7996 - val_accuracy: 0.7867 - 1s/epoch - 459us/sample
# Epoch 48/50
# 2700/2700 - 1s - loss: 0.0562 - accuracy: 0.9789 - val_loss: 0.8734 - val_accuracy: 0.7633 - 1s/epoch - 382us/sample
# Epoch 49/50
# 2700/2700 - 1s - loss: 0.0633 - accuracy: 0.9796 - val_loss: 0.7972 - val_accuracy: 0.7733 - 827ms/epoch - 306us/sample
# Epoch 50/50
# 2700/2700 - 1s - loss: 0.0609 - accuracy: 0.9789 - val_loss: 0.9080 - val_accuracy: 0.7867 - 904ms/epoch - 335us/sample

# %%
# sample text to check if fake or not
X = input("Enter the news text: ")

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# Enter the news text: Trudeau government proclaims annual day against gun violence
# This news is True
# C:\Users\KIIT\MachineLearning\Project\env\Lib\site-packages\keras\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
